# %% [markdown]
# ### Base Models: RFC and Logistic Regression
# February 6 2:00 after noon
#
# <div style="display: flex;">
#
# <div style="flex: 1; margin-right: 20px;">
#
# #### RFC (Base Model)
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.83     | 0.84     | 0.84      | 0.84         | -       |
# | Recall         | 0.97     | 0.41     | 0.69      | 0.84         | -       |
# | F1-Score       | 0.90     | 0.55     | 0.73      | 0.81         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.84    |
#
# </div>
#
# <div style="flex: 1;">
#
# #### Logistic Regression (Base Model)
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.87     | 0.77     | 0.82      | 0.85         | -       |
# | Recall         | 0.94     | 0.59     | 0.76      | 0.85         | -       |
# | F1-Score       | 0.91     | 0.67     | 0.79      | 0.85         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.85    |
#
# </div>
#
# </div>

# %% [markdown]
# ### Base Model Tested on Gold Test Data: 1_english_test
#
# | Model        | Accuracy   | Precision   | Recall     | F1 Score   |
# |--------------|------------|-------------|------------|------------|
# | Logistic Regression (LR) | 0.7361    | 0.4444      | 0.0909     | 0.1509     |
# | Random Forest Classifier (RFC) | 0.7361    | 0.4444      | 0.0909     | 0.1509     |

# %% [markdown]
# ### Adding TF-IDF Features
#
# <div style="display: flex;">
#
# <div style="flex: 1; margin-right: 20px;">
#
# #### RFC (New Model)
# **Dataset: checkworthy_3**
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.80     | 0.93     | 0.86      | 0.83         | -       |
# | Recall         | 0.99     | 0.24     | 0.62      | 0.81         | -       |
# | F1-Score       | 0.89     | 0.38     | 0.63      | 0.76         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.81    |
#
# </div>
#
# <div style="flex: 1;">
#
# #### Logistic Regression (New Model)
# **Dataset: checkworthy_3**
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.88     | 0.78     | 0.83      | 0.86         | -       |
# | Recall         | 0.94     | 0.62     | 0.78      | 0.86         | -       |
# | F1-Score       | 0.91     | 0.69     | 0.80      | 0.86         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.86    |
#
# </div>
#
# </div>

# %% [markdown]
# ### New Model with TF-IDF (10,000 Features) Tested on Gold Dataset
#
# | Model        | Accuracy   | Precision   | Recall     | F1 Score   |
# |--------------|------------|-------------|------------|------------|
# | Logistic Regression (LR) | 0.7683    | 0.5849      | 0.3523     | 0.4397     |
# | Random Forest Classifier (RFC) | 0.7478    | 0.7500      | 0.0341     | 0.0652     |

# %% [markdown]
# ### Random Forest: Over-Sampling vs. Under-Sampling
#
# <div style="display: flex;">
#
# <div style="flex: 1; margin-right: 20px;">
#
# #### Random Forest: Over-Sample
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.86     | 0.72     | 0.79      | 0.82         | -       |
# | Recall         | 0.93     | 0.53     | 0.73      | 0.83         | -       |
# | F1-Score       | 0.89     | 0.61     | 0.75      | 0.82         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.83    |
#
# </div>
#
# <div style="flex: 1;">
#
# #### Random Forest: Under-Sample
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.92     | 0.55     | 0.74      | 0.83         | -       |
# | Recall         | 0.78     | 0.80     | 0.79      | 0.79         | -       |
# | F1-Score       | 0.85     | 0.65     | 0.75      | 0.80         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.79    |
#
# </div>
#
# </div>

# %% [markdown]
# ### Random Forest Classifier: Over-Sampling vs. Under-Sampling (train data splited into train and test, and then testéd on gold data)
#
# | Sampling Method | Accuracy   | Precision   | Recall     | F1 Score   |
# |------------------|------------|-------------|------------|------------|
# | Under-Sampling | 0.7507    | 0.5165      | 0.5341     | 0.5251     |
# | Over-Sampling  | 0.7595    | 0.6500      | 0.1477     | 0.2407     |

# %% [markdown]
# ### Random Forest Classifier: Under-Sampling Results (whole train data was used for training, tested on gold data)
#
# | Sampling Method  | Accuracy | Precision | Recall | F1 Score |
# |------------------|----------|-----------|--------|----------|
# | Under-Sampling   | 0.7654   | 0.5465    | 0.5341 | 0.5402   |

# %% [markdown]
# ### Random Forest Classifier: Under-Sampling Data, Tuned Hyper Parameter
#
# | Sampling Method  | Accuracy | Precision | Recall | F1 Score |
# |------------------|----------|-----------|--------|----------|
# | Under-Sampling   | 0.7683   | 0.5464    | 0.6023 | 0.5730   |

# %% [markdown]
# # from IPython.display import Markdown
#
# # # Results for under-sampling
# # markdown_table = """
# # ### Random Forest Classifier: Under-Sampling Results
#
# # | Sampling Method  | Accuracy | Precision | Recall | F1 Score |
# # |------------------|----------|-----------|--------|----------|
# # | Under-Sampling   | 0.7654   | 0.5465    | 0.5341 | 0.5402   |
# # """
#
# # # Display the table as Markdown
# # display(Markdown(markdown_table))

# %% [markdown]
# ### Logistic Regression: Over-Sampling vs. Under-Sampling
#
# <div style="display: flex;">
#
# <div style="flex: 1; margin-right: 20px;">
#
# #### Logistic Regression: Over-Sample
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.93     | 0.65     | 0.79      | 0.86         | -       |
# | Recall         | 0.86     | 0.79     | 0.83      | 0.84         | -       |
# | F1-Score       | 0.89     | 0.71     | 0.80      | 0.85         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.84    |
#
# </div>
#
# <div style="flex: 1;">
#
# #### Logistic Regression: Under-Sample
#
# | Metric         | Class 0  | Class 1  | Macro Avg | Weighted Avg | Overall |
# |----------------|----------|----------|-----------|--------------|---------|
# | Precision      | 0.94     | 0.61     | 0.77      | 0.86         | -       |
# | Recall         | 0.83     | 0.83     | 0.83      | 0.83         | -       |
# | F1-Score       | 0.88     | 0.70     | 0.79      | 0.83         | -       |
# | Support        | 4229     | 1397     | -         | -            | 5626    |
# | Accuracy       | -        | -        | -         | -            | 0.83    |
#
# </div>
#
# </div>

# %% [markdown]
# ### Logistic Regression: Over-Sampling vs. Under-Sampling
#
# | Sampling Method | Accuracy   | Precision   | Recall     | F1 Score   |
# |------------------|------------|-------------|------------|------------|
# | Under-Sampling | 0.7625    | 0.6667      | 0.1591     | 0.2569     |
# | Over-Sampling  | 0.7537    | 0.5500      | 0.2500     | 0.3438     |

# %% [markdown]
# ## Model Performance Comparison
#
# | Sampling Method / Model      | Accuracy | Precision | Recall | F1 Score |
# |-----------------------------|----------|-----------|--------|----------|
# | **Under-Sampling RFC**      | 0.7507   | 0.5165    | 0.5341 | 0.5251   |
# | **Under-Sampling (RFC-HT)** | 0.7683   | 0.5464    | 0.6023 | 0.5730   |
# | **Original Imbalance (XGB)**| 0.7625   | 0.5393    | 0.5455 | 0.5424   |
# | **Under Sampling Data (XGB)**| 0.7302  | 0.48039   | 0.5568 | 0.5157  |

# %% [markdown]
# ## Model Performance Comparison
#
# | Sampling Method / Model      | Accuracy | Precision | Recall | F1 Score |
# |-----------------------------|----------|-----------|--------|----------|
# | **Under-Sampling RFC**      | 0.7507   | 0.5165    | 0.5341 | 0.5251   |
# | **Under-Sampling (RFC-HT)** | 0.7683   | 0.5464    | 0.6023 | 0.5730   |
# | **Original Imbalance (XGB)**| 0.7625   | 0.5393    | 0.5455 | 0.5424   |
# | **Under Sampling Data (XGB)**| 0.7302  | 0.48039   | 0.5568 | 0.5157   |
# | **Balanced Dataset (XGB)**  | 0.7900   | 0.5800    | 0.7000 | 0.6700   |
# | **Balanced Dataset (XGB)**  | 0.80     | 0.60      | 0.67   | 0.7000   |
#
# ### Best Hyperparameters for XGB (Balanced Dataset)
# ```python
# best_params = {
#     'learning_rate': 0.09460545700275623,
#     'max_depth': 10,  # Originally tested with 20
#     'n_estimators': 400,
#     'subsample': 0.8,  # Originally 0.5115069174630871
#     'colsample_bytree': 0.8,
#     'tree_method': 'hist'
# }
# PCA : 356
# tf-idf : 4300

# %%
# after dropping the NONE = Trues from only No  class and then balances
# XGB on balance dataset
# Accuracy: 0.82
# Precision: 0.67
# Recall: 0.56
# F1 Score: 0.56

# labels	
# 0	7189
# 1	5408

# %%
# after dropping the NONE = Trues fro all class, balanced
# XGB on balance dataset
# Accuracy: 0.83
# Precision: 0.72
# Recall: 0.55
# F1 Score: 0.62

# labels	
# 0	4159
# 1	4159

# %%
# XGB with only embedding (356 features) , dropping None = True for only No class
# XGB on balance dataset
# Accuracy: 0.62
# Precision: 0.39
# Recall: 0.88
# F1 Score: 0.54


# KNN with only embedding (356 features) , dropping None = True for only No class
# KNN on balance dataset
# Accuracy: 0.62
# Precision: 0.39
# Recall: 0.88
# F1 Score: 0.54

---------------------------------------------------- so far best ---------------------------------
# XGB with rus with all selected features,  , dropping None = True for only No class

# XGB on balance dataset
# Accuracy: 0.80
# Precision: 0.60
# Recall: 0.67
# F1 Score: 0.63

# XGB with tomeklink with all selected features,  , dropping None = True for only No class

# XGB on balance dataset
# Accuracy: 0.82
# Precision: 0.67
# Recall: 0.61
# F1 Score: 0.64

# KNN with tomeklink with all selected features,with standard scalling  , dropping None = True for only No class
# KNN on balance dataset
# Accuracy: 0.65
# Precision: 0.67
# Recall: 0.65
# F1 Score: 0.66

# KNN with rus with all selected features, with standard scalling, dropping None = True for only No class
# KNN on balance dataset
# Accuracy: 0.64
# Precision: 0.67
# Recall: 0.64
# F1 Score: 0.65

--------------------------------------------------------------------------------------------------

# XGB with enn with all selected features,  , dropping None = True for only No class

# XGB on balance dataset
# Accuracy: 0.68
# Precision: 0.43
# Recall: 0.81
# F1 Score: 0.56
# Out:
#   Cell In[1], line 8
#     ---------------------------------------------------- so far best ---------------------------------
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# model performance without resampling, hp tuned:

Metrices for: XGBClassifier(base_score=None, booster=None, callbacks=None,
              colsample_bylevel=None, colsample_bynode=None,
              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
              enable_categorical=False, eval_metric='logloss',
              feature_types=None, gamma=0, grow_policy=None,
              importance_type=None, interaction_constraints=None,
              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
              max_cat_to_onehot=None, max_delta_step=None, max_depth=30,
              max_leaves=None, min_child_weight=5, missing=nan,
              monotone_constraints=None, multi_strategy=None, n_estimators=1742,
              n_jobs=None, num_parallel_tree=None, random_state=None, ...) without resampling technique (12597, 4666)

Accuracy: 0.80
Precision: 0.60
Recall: 0.68
F1 Score: 0.64
Metrices for: GradientBoostingClassifier(learning_rate=0.27616382277289797,
                           min_samples_leaf=5, min_samples_split=16,
                           n_estimators=255, subsample=0.9244569121330419) without resampling technique (12597, 4666)

Accuracy: 0.81
Precision: 0.62
Recall: 0.68
F1 Score: 0.65
[LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=5. Current value: min_data_in_leaf=5
[LightGBM] [Warning] Unknown parameter: min_samples_split
Metrices for: LGBMClassifier(learning_rate=0.27616382277289797, max_depth=3,
               max_features=None, min_samples_leaf=5, min_samples_split=16,
               n_estimators=255, subsample=0.9244569121330419) without resampling technique (12597, 4666)

Accuracy: 0.80
Precision: 0.60
Recall: 0.64
F1 Score: 0.62

# %%
# model performance 

best_param_lgbm = {
 'bagging_fraction': 0.856135294962221,
 'bagging_freq': 4,
 'feature_fraction': 0.6424202471887338,
 'lambda_l1': 0.036886947354532795,
 'lambda_l2': 0.6095643339798968,
 'learning_rate': 0.16080370696865845,
 'max_depth': 8,
 'min_child_samples': 32,
 'n_estimators': 278,
 'num_leaves': 20
}

# %%
# model performance without CNN, hp tuned:

Metrices for: XGBClassifier(base_score=None, booster=None, callbacks=None,
              colsample_bylevel=None, colsample_bynode=None,
              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
              enable_categorical=False, eval_metric='logloss',
              feature_types=None, gamma=0, grow_policy=None,
              importance_type=None, interaction_constraints=None,
              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
              max_cat_to_onehot=None, max_delta_step=None, max_depth=30,
              max_leaves=None, min_child_weight=5, missing=nan,
              monotone_constraints=None, multi_strategy=None, n_estimators=1742,
              n_jobs=None, num_parallel_tree=None, random_state=None, ...) without resampling technique (12597, 4666)

Metrices for: xgbcnn

Accuracy: 0.83
Precision: 0.78
Recall: 0.75
F1 Score: 0.76
Metrices for: GradientBoostingClassifier(learning_rate=0.27616382277289797,
                           min_samples_leaf=5, min_samples_split=16,
                           n_estimators=255, subsample=0.9244569121330419) without resampling technique (12597, 4666)

Accuracy: 0.81
Precision: 0.62
Recall: 0.68
F1 Score: 0.65
[LightGBM] [Warning] min_data_in_leaf is set with min_child_samples=20, will be overridden by min_samples_leaf=5. Current value: min_data_in_leaf=5
[LightGBM] [Warning] Unknown parameter: min_samples_split
Metrices for: LGBMClassifier(learning_rate=0.27616382277289797, max_depth=3,
               max_features=None, min_samples_leaf=5, min_samples_split=16,
               n_estimators=255, subsample=0.9244569121330419) without resampling technique (12597, 4666)

Metrices for: lgbmcnn

Accuracy: 0.78
Precision: 0.75
Recall: 0.72
F1 Score: 0.73


Metrices for: knntmk

Accuracy: 0.8
Precision: 0.6
Recall: 0.64
F1 Score: 0.62

# %%
# Accuracy: 0.78
# Precision: 0.75
# Recall: 0.72
# F1 Score: 0.73

# Accuracy: 0.83
# Precision: 0.78
# Recall: 0.75
# F1 Score: 0.76


# Accuracy: 0.80
# Precision: 0.60
# Recall: 0.64
# F1 Score: 0.62

# %%
cnn: labels
1    5408
0    2890
Name: count, dtype: int64
enn: labels
1    5408
0    2973
Name: count, dtype: int64
rus: labels
0    5408
1    5408
Name: count, dtype: int64
tml: labels
0    6678
1    5408
Name: count, dtype: int64

# %%
## ensembling Voating soft (knn, xgb, dt, rfc), hp tuned, no sampling only pruning, 
total data: Trained on

count
labels	
0	7189
1	5408

# test on gold data
# 300 + data
# Voating Soft
Accuracy: 0.80
Precision: 0.79
Recall: 0.80
F1 Score: 0.80

# DT
Accuracy: 0.72
Precision: 0.73
Recall: 0.72
F1 Score: 0.72

# KNN
Accuracy: 0.67
Precision: 0.67
Recall: 0.67
F1 Score: 0.67

# XGB
Accuracy: 0.79
Precision: 0.80
Recall: 0.79
F1 Score: 0.80

# RFC
Accuracy: 0.74
Precision: 0.73
Recall: 0.74
F1 Score: 0.73
# Out:
#   Cell In[1], line 2
#     total data:
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
